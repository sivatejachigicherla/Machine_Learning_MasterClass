# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import load_iris
dataset = load_iris()
dir(dataset)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target', 'target_names']

# %%
from sklearn import tree
clf = tree.DecisionTreeRegressor() #object of DTR
X_train, X_test, y_train, y_test = train_test_split(dataset.data, dataset.target)
clf = clf.fit(X_train,y_train)

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(clf,filled="True")
# Out:
# [Text(418.5, 498.3, 'X[3] <= 0.8\nmse = 0.643\nsamples = 112\nvalue = 1.0'),
#  Text(354.11538461538464, 407.70000000000005, 'mse = 0.0\nsamples = 36\nvalue = 0.0'),
#  Text(482.8846153846154, 407.70000000000005, 'X[3] <= 1.75\nmse = 0.249\nsamples = 76\nvalue = 1.474'),
#  Text(257.53846153846155, 317.1, 'X[2] <= 5.05\nmse = 0.084\nsamples = 43\nvalue = 1.093'),
#  Text(128.76923076923077, 226.5, 'X[3] <= 1.65\nmse = 0.025\nsamples = 39\nvalue = 1.026'),
#  Text(64.38461538461539, 135.89999999999998, 'mse = 0.0\nsamples = 37\nvalue = 1.0'),
#  Text(193.15384615384616, 135.89999999999998, 'X[1] <= 2.75\nmse = 0.25\nsamples = 2\nvalue = 1.5'),
#  Text(128.76923076923077, 45.299999999999955, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(257.53846153846155, 45.299999999999955, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(386.3076923076923, 226.5, 'X[0] <= 6.05\nmse = 0.188\nsamples = 4\nvalue = 1.75'),
#  Text(321.9230769230769, 135.89999999999998, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(450.69230769230774, 135.89999999999998, 'mse = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(708.2307692307693, 317.1, 'X[2] <= 4.85\nmse = 0.029\nsamples = 33\nvalue = 1.97'),
#  Text(643.8461538461538, 226.5, 'X[1] <= 3.1\nmse = 0.222\nsamples = 3\nvalue = 1.667'),
#  Text(579.4615384615385, 135.89999999999998, 'mse = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(708.2307692307693, 135.89999999999998, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(772.6153846153846, 226.5, 'mse = 0.0\nsamples = 30\nvalue = 2.0')]

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9736842105263158
